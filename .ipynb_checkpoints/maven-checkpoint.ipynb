# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



from datetime import datetime

# %% [markdown]
# # customers data

# %%
customersdf=pd.read_csv('C:\\Users\\User\\Desktop\\Rasheedat tafa\\maven power bi\\maven market report\\csv\\MavenMarket_Customers.csv')

# %%
customersdf.head()
# Out:
#    customer_id  customer_acct_num first_name  last_name    customer_address  \
# 0            1        87462024688      Sheri     Nowmer    2433 Bailey Road
# 1            2        87470586299    Derrick    Whelply  2219 Dewing Avenue
# 2            3        87475757600     Jeanne      Derry     7640 First Ave.
# 3            4        87500482201    Michael     Spence       337 Tosca Way
# 4            5        87514054179       Maya  Gutierrez     8668 Via Neruda
#
#   customer_city customer_state_province  customer_postal_code  \
# 0      Tlaxiaco                  Oaxaca                 15057
# 1         Sooke                      BC                 17172
# 2      Issaquah                      WA                 73980
# 3       Burnaby                      BC                 74674
# 4        Novato                      CA                 57355
#
#   customer_country  birthdate marital_status yearly_income gender  \
# 0           Mexico  8/26/1961              M   $30K - $50K      F
# 1           Canada   7/3/1915              S   $70K - $90K      M
# 2              USA  6/21/1910              M   $50K - $70K      F
# 3           Canada  6/20/1969              M   $10K - $30K      M
# 4              USA  5/10/1951              S   $30K - $50K      F
#
#    total_children  num_children_at_home            education acct_open_date  \
# 0               4                     2  Partial High School      9/10/1991
# 1               1                     0  Partial High School      3/11/1993
# 2               1                     1     Bachelors Degree      6/11/1991
# 3               4                     4  Partial High School      5/21/1994
# 4               3                     0      Partial College      8/21/1992
#
#   member_card      occupation homeowner
# 0      Bronze  Skilled Manual         Y
# 1      Bronze    Professional         N
# 2      Bronze    Professional         Y
# 3      Normal  Skilled Manual         N
# 4      Silver          Manual         N

# %%
customersdf.shape
# Out:
# (10281, 20)

# %%
customersdf.columns
# Out:
# Index(['customer_id', 'customer_acct_num', 'first_name', 'last_name',
#        'customer_address', 'customer_city', 'customer_state_province',
#        'customer_postal_code', 'customer_country', 'birthdate',
#        'marital_status', 'yearly_income', 'gender', 'total_children',
#        'num_children_at_home', 'education', 'acct_open_date', 'member_card',
#        'occupation', 'homeowner'],
#       dtype='object')

# %%
customers=customersdf[['customer_id','first_name', 'last_name','customer_city', 'customer_state_province',
       'customer_postal_code', 'customer_country', 'birthdate',
       'marital_status', 'yearly_income', 'gender', 'total_children',
        'education', 'member_card',
       'occupation', 'homeowner']]

# %%
customers.isnull().sum()
# Out:
# customer_id                0
# first_name                 0
# last_name                  0
# customer_city              0
# customer_state_province    0
# customer_postal_code       0
# customer_country           0
# birthdate                  0
# marital_status             0
# yearly_income              0
# gender                     0
# total_children             0
# education                  0
# member_card                0
# occupation                 0
# homeowner                  0
# dtype: int64

# %%
customers.dtypes
# Out:
# customer_id                 int64
# first_name                 object
# last_name                  object
# customer_city              object
# customer_state_province    object
# customer_postal_code        int64
# customer_country           object
# birthdate                  object
# marital_status             object
# yearly_income              object
# gender                     object
# total_children              int64
# education                  object
# member_card                object
# occupation                 object
# homeowner                  object
# dtype: object

# %%
plt.figure(figsize=(10,4),dpi=90)
sns.countplot(data=customers,x='customer_country')
plt.title('coustomers per country')
# Out:
# Text(0.5, 1.0, 'coustomers per country')

# %%
plt.figure(figsize=(10,4),dpi=100)
sns.histplot(data=customers,x='yearly_income')
plt.title('coustomers vs yearly income')
# Out:
# Text(0.5, 1.0, 'coustomers vs yearly income')

# %%
plt.figure(figsize=(10,4),dpi=80)
sns.countplot(data=customers,x='gender')
plt.title('coustomers gender')
# Out:
# Text(0.5, 1.0, 'coustomers gender')

# %% [markdown]
# # TRANSACTIONS

# %%
transactions1998=pd.read_csv('C:\\Users\\User\\Desktop\\Rasheedat tafa\\maven power bi\\maven market report\\csv\\transactions\\MavenMarket_Transactions_1998.csv')

# %%
transactions1997=pd.read_csv('C:\\Users\\User\\Desktop\\Rasheedat tafa\\maven power bi\\maven market report\\csv\\transactions\\MavenMarket_Transactions_1997.csv')

# %% [markdown]
# # joining the transactions tabales

# %%
transactionjoined=pd.concat([transactions1998,transactions1997])

# %%
transactionjoined
# Out:
#       transaction_date  stock_date  product_id  customer_id  store_id  \
# 0             1/1/1998  12/25/1997           4         2439        10
# 1             1/1/1998  12/28/1997          11         4284        10
# 2             1/1/1998  12/28/1997          12          534        10
# 3             1/1/1998  12/29/1997          14         9743        10
# 4             1/1/1998  12/27/1997          16         3608        10
# ...                ...         ...         ...          ...       ...
# 86832       12/30/1997  12/29/1997        1376         7043        14
# 86833       12/30/1997  12/26/1997        1380         7043        14
# 86834       12/30/1997  12/23/1997         637         7043        14
# 86835       12/30/1997  12/29/1997         930         2145        14
# 86836       12/30/1997  12/28/1997         427         2145        14
#
#        quantity
# 0             3
# 1             3
# 2             3
# 3             2
# 4             3
# ...         ...
# 86832         2
# 86833         1
# 86834         2
# 86835         1
# 86836         2
#
# [269720 rows x 6 columns]

# %% [markdown]
# # extracting month and year from transaction date

# %%
transactionjoined['date'] = pd.to_datetime(transactionjoined['transaction_date'])

# %%
transactionjoined['month'] = transactionjoined['date'].dt.month_name().str[:3]

# %%
transactionjoined['year'] = transactionjoined['date'].dt.year

# %%
transactionjoined
# Out:
#       transaction_date  stock_date  product_id  customer_id  store_id  \
# 0             1/1/1998  12/25/1997           4         2439        10
# 1             1/1/1998  12/28/1997          11         4284        10
# 2             1/1/1998  12/28/1997          12          534        10
# 3             1/1/1998  12/29/1997          14         9743        10
# 4             1/1/1998  12/27/1997          16         3608        10
# ...                ...         ...         ...          ...       ...
# 86832       12/30/1997  12/29/1997        1376         7043        14
# 86833       12/30/1997  12/26/1997        1380         7043        14
# 86834       12/30/1997  12/23/1997         637         7043        14
# 86835       12/30/1997  12/29/1997         930         2145        14
# 86836       12/30/1997  12/28/1997         427         2145        14
#
#        quantity       date month  year
# 0             3 1998-01-01   Jan  1998
# 1             3 1998-01-01   Jan  1998
# 2             3 1998-01-01   Jan  1998
# 3             2 1998-01-01   Jan  1998
# 4             3 1998-01-01   Jan  1998
# ...         ...        ...   ...   ...
# 86832         2 1997-12-30   Dec  1997
# 86833         1 1997-12-30   Dec  1997
# 86834         2 1997-12-30   Dec  1997
# 86835         1 1997-12-30   Dec  1997
# 86836         2 1997-12-30   Dec  1997
#
# [269720 rows x 9 columns]

# %%
transactionjoined.columns
# Out:
# Index(['transaction_date', 'stock_date', 'product_id', 'customer_id',
#        'store_id', 'quantity', 'date', 'month', 'year'],
#       dtype='object')

# %%
transactions=transactionjoined[['date',  'year', 'month','stock_date', 'product_id', 'customer_id',
       'store_id', 'quantity']]

# %%
transactions
# Out:
#             date  year month  stock_date  product_id  customer_id  store_id  \
# 0     1998-01-01  1998   Jan  12/25/1997           4         2439        10
# 1     1998-01-01  1998   Jan  12/28/1997          11         4284        10
# 2     1998-01-01  1998   Jan  12/28/1997          12          534        10
# 3     1998-01-01  1998   Jan  12/29/1997          14         9743        10
# 4     1998-01-01  1998   Jan  12/27/1997          16         3608        10
# ...          ...   ...   ...         ...         ...          ...       ...
# 86832 1997-12-30  1997   Dec  12/29/1997        1376         7043        14
# 86833 1997-12-30  1997   Dec  12/26/1997        1380         7043        14
# 86834 1997-12-30  1997   Dec  12/23/1997         637         7043        14
# 86835 1997-12-30  1997   Dec  12/29/1997         930         2145        14
# 86836 1997-12-30  1997   Dec  12/28/1997         427         2145        14
#
#        quantity
# 0             3
# 1             3
# 2             3
# 3             2
# 4             3
# ...         ...
# 86832         2
# 86833         1
# 86834         2
# 86835         1
# 86836         2
#
# [269720 rows x 8 columns]

# %%
transactions.describe().transpose()
# Out:
#                 count         mean          std     min     25%     50%  \
# year         269720.0  1997.678048     0.467226  1997.0  1997.0  1998.0
# product_id   269720.0   783.862873   447.926131     1.0   396.0   787.0
# customer_id  269720.0  5119.390405  2901.883077     3.0  2570.0  5090.0
# store_id     269720.0    12.753730     6.349746     1.0     7.0    13.0
# quantity     269720.0     3.090201     0.835554     1.0     3.0     3.0
#
#                 75%      max
# year         1998.0   1998.0
# product_id   1174.0   1559.0
# customer_id  7614.0  10281.0
# store_id       17.0     24.0
# quantity        4.0      6.0

# %%
transactions.isnull().sum()
# Out:
# date           0
# year           0
# month          0
# stock_date     0
# product_id     0
# customer_id    0
# store_id       0
# quantity       0
# dtype: int64

# %%
monthlyorders = pd.DataFrame(transactions.groupby('month')['quantity'].sum())
monthlysort = monthlyorders.sort_values(by='quantity', ascending=False)
monthlysort
# Out:
#        quantity
# month
# Dec       83525
# Nov       79077
# Jul       70434
# Mar       70040
# Sep       68352
# Jan       67941
# Jun       66961
# Aug       66474
# May       66166
# Feb       65388
# Apr       65228
# Oct       63903

# %%
plt.figure(figsize=(12,4),dpi=100)
sns.barplot(x=monthlysort.index, y=monthlysort['quantity'])
plt.title('quantity sold per month')
# Out:
# Text(0.5, 1.0, 'quantity sold per month')

# %%
yearlysales=pd.DataFrame(transactions.groupby('year')['quantity'].sum())
yearlysales
# Out:
#       quantity
# year
# 1997    266773
# 1998    566716

# %%
plt.figure(figsize=(10,4),dpi=90)
sns.barplot(x=yearlysales.index, y=yearlysales['quantity'])
plt.title('Yearly sales')
# Out:
# Text(0.5, 1.0, 'Yearly sales')

# %% [markdown]
# # PRODUCT TABLE

# %%
productdf=pd.read_csv('C:\\Users\\User\\Desktop\\Rasheedat tafa\\maven power bi\\maven market report\\csv\\MavenMarket_products.csv')

# %%
productdf.head()
# Out:
#    product_id product_brand                 product_name  product_sku  \
# 0           1    Washington       Washington Berry Juice  90748583674
# 1           2    Washington       Washington Mango Drink  96516502499
# 2           3    Washington  Washington Strawberry Drink  58427771925
# 3           4    Washington        Washington Cream Soda  64412155747
# 4           5    Washington         Washington Diet Soda  85561191439
#
#    product_retail_price  product_cost  product_weight  recyclable  low_fat
# 0                  2.85          0.94            8.39         NaN      NaN
# 1                  0.74          0.26            7.42         NaN      1.0
# 2                  0.83          0.40           13.10         1.0      1.0
# 3                  3.64          1.64           10.60         1.0      NaN
# 4                  2.19          0.77            6.66         1.0      NaN

# %%
productdf.describe().transpose()
# Out:
#                        count          mean           std           min  \
# product_id            1560.0  7.805000e+02  4.504775e+02  1.000000e+00
# product_sku           1560.0  5.562930e+10  2.580380e+10  1.003103e+10
# product_retail_price  1560.0  2.117282e+00  9.327793e-01  5.000000e-01
# product_cost          1560.0  8.539679e-01  4.044001e-01  1.600000e-01
# product_weight        1560.0  1.380482e+01  4.631014e+00  6.000000e+00
# recyclable             873.0  1.000000e+00  0.000000e+00  1.000000e+00
# low_fat                552.0  1.000000e+00  0.000000e+00  1.000000e+00
#
#                                25%           50%           75%           max
# product_id            3.907500e+02  7.805000e+02  1.170250e+03  1.560000e+03
# product_sku           3.345056e+10  5.629308e+10  7.798317e+10  9.998368e+10
# product_retail_price  1.417500e+00  2.130000e+00  2.792500e+00  3.980000e+00
# product_cost          5.400000e-01  8.200000e-01  1.130000e+00  1.970000e+00
# product_weight        9.657500e+00  1.360000e+01  1.772500e+01  2.190000e+01
# recyclable            1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# low_fat               1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00

# %%
productdf.isnull().sum()
# Out:
# product_id                 0
# product_brand              0
# product_name               0
# product_sku                0
# product_retail_price       0
# product_cost               0
# product_weight             0
# recyclable               687
# low_fat                 1008
# dtype: int64

# %% [markdown]
# # STORES TABLE

# %%
storesdf=pd.read_csv('C:\\Users\\User\\Desktop\\Rasheedat tafa\\maven power bi\\maven market report\\csv\\MavenMarket_Stores.csv')

# %%
storesdf.head()
# Out:
#    store_id  region_id           store_type store_name store_street_address  \
# 0         1         28          Supermarket    Store 1       2853 Bailey Rd
# 1         2         78        Small Grocery    Store 2   5203 Catanzaro Way
# 2         3         76          Supermarket    Store 3   1501 Ramsey Circle
# 3         4         27  Gourmet Supermarket    Store 4     433 St George Dr
# 4         5          4        Small Grocery    Store 5   1250 Coggins Drive
#
#     store_city store_state store_country   store_phone first_opened_date  \
# 0     Acapulco    Guerrero        Mexico  262-555-5124          1/9/1982
# 1   Bellingham          WA           USA  605-555-8203          4/2/1970
# 2    Bremerton          WA           USA  509-555-1596         6/14/1959
# 3      Camacho   Zacatecas        Mexico  304-555-1474         9/27/1994
# 4  Guadalajara     Jalisco        Mexico  801-555-4324         9/18/1978
#
#   last_remodel_date  total_sqft  grocery_sqft
# 0         12/5/1990       23593         17475
# 1          6/4/1973       28206         22271
# 2        11/19/1967       39696         24390
# 3         12/1/1995       23759         16844
# 4         6/29/1991       24597         15012

# %%
storesdf.isnull().sum()
# Out:
# store_id                0
# region_id               0
# store_type              0
# store_name              0
# store_street_address    0
# store_city              0
# store_state             0
# store_country           0
# store_phone             0
# first_opened_date       0
# last_remodel_date       0
# total_sqft              0
# grocery_sqft            0
# dtype: int64

# %% [markdown]
# # MERGING THE DATA SETS

# %%
merged1 = pd.merge(transactions, customers, on='customer_id', how='inner')

# %%
merged2= pd.merge(merged1, productdf, on='product_id', how='inner')

# %%
merged2= pd.merge(merged1, productdf, on='product_id', how='inner')

# %%
merged3= pd.merge(merged2, storesdf, on='store_id', how='inner')

# %%
merged3.columns
# Out:
# Index(['date', 'year', 'month', 'stock_date', 'product_id', 'customer_id',
#        'store_id', 'quantity', 'first_name', 'last_name', 'customer_city',
#        'customer_state_province', 'customer_postal_code', 'customer_country',
#        'birthdate', 'marital_status', 'yearly_income', 'gender',
#        'total_children', 'education', 'member_card', 'occupation', 'homeowner',
#        'product_brand', 'product_name', 'product_sku', 'product_retail_price',
#        'product_cost', 'product_weight', 'recyclable', 'low_fat', 'region_id',
#        'store_type', 'store_name', 'store_street_address', 'store_city',
#        'store_state', 'store_country', 'store_phone', 'first_opened_date',
#        'last_remodel_date', 'total_sqft', 'grocery_sqft'],
#       dtype='object')

# %%
mavensales=merged3[['date', 'year', 'month', 'stock_date',
        'first_name', 'last_name', 'customer_city', 'customer_country',
       'birthdate', 'marital_status', 'yearly_income', 'gender',
       'total_children', 'member_card', 'occupation', 'homeowner',
       'store_city',
       'store_state', 'store_country', 'first_opened_date',
       'last_remodel_date',  'recyclable', 'low_fat','product_brand','product_name',
       
       'product_cost','quantity','product_retail_price']]

# %%
mavensales.head()
# Out:
#         date  year month  stock_date first_name last_name customer_city  \
# 0 1998-01-01  1998   Jan  12/25/1997      Joyce    Furrer       Orizaba
# 1 1998-12-14  1998   Dec   12/7/1998      James   Dennard       Orizaba
# 2 1998-08-29  1998   Aug   8/22/1998   Nicholas  Takemura       Orizaba
# 3 1998-04-15  1998   Apr    4/8/1998    Carolyn    Staton       Orizaba
# 4 1998-03-07  1998   Mar   2/28/1998      Allan  Marchman       Orizaba
#
#   customer_country   birthdate marital_status  ... store_country  \
# 0           Mexico   4/17/1924              S  ...        Mexico
# 1           Mexico   7/21/1949              S  ...        Mexico
# 2           Mexico  10/21/1957              M  ...        Mexico
# 3           Mexico   5/14/1970              S  ...        Mexico
# 4           Mexico   4/28/1976              M  ...        Mexico
#
#   first_opened_date  last_remodel_date recyclable low_fat product_brand  \
# 0         4/13/1979          1/30/1982        1.0     NaN    Washington
# 1         4/13/1979          1/30/1982        1.0     NaN    Washington
# 2         4/13/1979          1/30/1982        1.0     NaN    Washington
# 3         4/13/1979          1/30/1982        1.0     NaN    Washington
# 4         4/13/1979          1/30/1982        1.0     NaN    Washington
#
#             product_name product_cost quantity product_retail_price
# 0  Washington Cream Soda         1.64        3                 3.64
# 1  Washington Cream Soda         1.64        5                 3.64
# 2  Washington Cream Soda         1.64        4                 3.64
# 3  Washington Cream Soda         1.64        2                 3.64
# 4  Washington Cream Soda         1.64        5                 3.64
#
# [5 rows x 28 columns]

# %%
mavensales['costprice']=mavensales['quantity']* mavensales['product_cost']
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_21348\3635215427.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mavensales['costprice']=mavensales['quantity']* mavensales['product_cost']

# %%
mavensales['revenue']=mavensales['quantity']* mavensales['product_retail_price']
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_21348\2609577327.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mavensales['revenue']=mavensales['quantity']* mavensales['product_retail_price']

# %%
mavensales['profit']=mavensales['revenue']-mavensales['costprice']
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_21348\2782998641.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mavensales['profit']=mavensales['revenue']-mavensales['costprice']

# %%
mavensales.head()
# Out:
#         date  year month  stock_date first_name last_name customer_city  \
# 0 1998-01-01  1998   Jan  12/25/1997      Joyce    Furrer       Orizaba
# 1 1998-12-14  1998   Dec   12/7/1998      James   Dennard       Orizaba
# 2 1998-08-29  1998   Aug   8/22/1998   Nicholas  Takemura       Orizaba
# 3 1998-04-15  1998   Apr    4/8/1998    Carolyn    Staton       Orizaba
# 4 1998-03-07  1998   Mar   2/28/1998      Allan  Marchman       Orizaba
#
#   customer_country   birthdate marital_status  ... recyclable low_fat  \
# 0           Mexico   4/17/1924              S  ...        1.0     NaN
# 1           Mexico   7/21/1949              S  ...        1.0     NaN
# 2           Mexico  10/21/1957              M  ...        1.0     NaN
# 3           Mexico   5/14/1970              S  ...        1.0     NaN
# 4           Mexico   4/28/1976              M  ...        1.0     NaN
#
#    product_brand           product_name product_cost quantity  \
# 0     Washington  Washington Cream Soda         1.64        3
# 1     Washington  Washington Cream Soda         1.64        5
# 2     Washington  Washington Cream Soda         1.64        4
# 3     Washington  Washington Cream Soda         1.64        2
# 4     Washington  Washington Cream Soda         1.64        5
#
#   product_retail_price costprice revenue profit
# 0                 3.64      4.92   10.92    6.0
# 1                 3.64      8.20   18.20   10.0
# 2                 3.64      6.56   14.56    8.0
# 3                 3.64      3.28    7.28    4.0
# 4                 3.64      8.20   18.20   10.0
#
# [5 rows x 31 columns]

# %%
mavensales.describe().transpose()
# Out:
#                           count         mean       std      min      25%  \
# year                  4130185.0  1997.787877  0.408812  1997.00  1998.00
# total_children        4130185.0     2.546358  1.492219     0.00     1.00
# recyclable            2316311.0     1.000000  0.000000     1.00     1.00
# low_fat               1461245.0     1.000000  0.000000     1.00     1.00
# quantity_returned     4130185.0     1.168102  0.373957     1.00     1.00
# product_cost          4130185.0     0.853770  0.403490     0.16     0.54
# quantity              4130185.0     3.108019  0.826234     1.00     3.00
# product_retail_price  4130185.0     2.117100  0.931162     0.50     1.42
# costprice             4130185.0     2.652025  1.474437     0.16     1.52
# revenue               4130185.0     6.576682  3.463241     0.50     3.84
# profit                4130185.0     3.924657  2.096160     0.25     2.31
#
#                           50%      75%      max
# year                  1998.00  1998.00  1998.00
# total_children           3.00     4.00     5.00
# recyclable               1.00     1.00     1.00
# low_fat                  1.00     1.00     1.00
# quantity_returned        1.00     1.00     2.00
# product_cost             0.82     1.13     1.97
# quantity                 3.00     4.00     6.00
# product_retail_price     2.13     2.79     3.98
# costprice                2.40     3.54    10.80
# revenue                  5.98     8.70    23.64
# profit                   3.60     5.24    15.24

# %%
monthlyrevenue = pd.DataFrame(mavensales.groupby('month')[['revenue','profit','quantity_returned']].sum())
revenuesort = monthlyrevenue.sort_values(by='revenue', ascending=False)
monthrevenue=revenuesort.reset_index()
monthrevenue
# Out:
#    month     revenue      profit  quantity_returned
# 0    Dec  3204266.80  1911217.71             559985
# 1    Nov  2628838.56  1568551.83             464330
# 2    Jul  2445307.06  1460149.45             424487
# 3    Jan  2291132.96  1369496.78             405528
# 4    Sep  2275637.96  1357403.54             396689
# 5    Oct  2207237.55  1314108.30             394824
# 6    Mar  2204342.99  1314693.96             396586
# 7    May  2171995.34  1298423.19             387111
# 8    Feb  2093473.37  1250702.80             375262
# 9    Jun  2029333.32  1211152.77             366531
# 10   Apr  1863467.70  1111438.19             338586
# 11   Aug  1747879.34  1042221.29             314559

# %%
mavensales['revenue'].sum()
# Out:
# 1764546.44

# %%
mavensales['profit'].sum()
# Out:
# 1052818.78

# %%
mavensales['quantity'].sum()
# Out:
# 833489

# %%
plt.figure(figsize=(18,4),dpi=150)
monthrevenue.plot(kind='line', x='month', y='revenue')
#monthrevenue.plot(kind='line', x='month', y='profit')
#plt.title('Monthly Revenue')
#plt.xlabel('Month')
#plt.ylabel('Revenue')
# Out:
# <AxesSubplot:xlabel='month'>

# %%
plt.figure(figsize=(18,4),dpi=150)
monthrevenue.plot(kind='line', x='month', y='revenue')
# Out:
# <AxesSubplot:xlabel='month'>

# %%
plt.plot(monthrevenue.index, monthlyrevenue['revenue'], label='Revenue')
plt.plot(monthrevenue.index, monthlyrevenue['profit'], label='Profit')
